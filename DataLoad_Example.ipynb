# %% [markdown]
# <a href="https://colab.research.google.com/github/Falconwatch/MarketKing/blob/feature%2Fdata_loader/DataLoad_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install yfinance

# %%
from methods import load_data
# %matplotlib inline

# %%
msft_data = load_data("MSFT", period_start="2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
msft_data["Open"].plot()
